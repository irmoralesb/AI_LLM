# %% [markdown]
# # Editing Text
#
# > client.chat.completions.create

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

client = OpenAI()

# %% [markdown]
# ## Text Editing

# %%
prompt = """
Update name to Maarten, pronouns to he/him, and job title to Senior Content Developer in the following text:

Joanne is a content developer at DataCamp. Her favorite programming language is R, which she uses for her statistical analyses.
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role":"user", "content": prompt}]
)

print(response.choices[0].message.content)
# Out:
# Maarten is a Senior Content Developer at DataCamp. His favorite programming language is R, which he uses for his statistical analyses.

# %% [markdown]
# ## Text Summarization

# %%
file_path = "../resources/text_summarization_example.txt"

with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

prompt = f"""
Summarize the customer support chat in three concise key points: {text}
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role":"user","content":f"{prompt}"}]
)


print(response.choices[0].message.content)
# Out:
# 1. María's AeroSound H300 wireless headphones stopped charging and do not turn on, prompting her to seek support.
# 2. Support confirmed that the headphones are still under warranty and diagnosed a likely hardware failure in the charging module.
# 3. To proceed with the warranty claim, María needs to provide a photo of the serial number, proof of purchase, and her shipping address, with the replacement process expected to take 7–10 business days.

# %% [markdown]
# ## Controlling Output Text
#
# > max_completion_tokens
#
# * It's used to control how many text is used in the output

# %%
file_path = "../resources/text_summarization_example.txt"
max_tokens_to_use = 5

with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

prompt = f"""
Summarize the customer support chat in three concise key points: {text}
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    max_completion_tokens= max_tokens_to_use,
    messages=[{"role":"user","content":f"{prompt}"}]
)


print(response.choices[0].message.content)
# Out:
# 1. María's Aero
