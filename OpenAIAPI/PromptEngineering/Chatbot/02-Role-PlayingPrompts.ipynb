# %% [markdown]
# # Role-playing prompts for chatbot
#
# * Tell chatbot to play a specific role
# * Chatbot -> actor in play
# * Chatbot adjust to match role
# * Tailored language and content to fit the persona
# * More effective interactions
#
#
# ## Role-Playing Example
#
# **Question**: Could you give me technical specifications of Product X that your company offers?
#
# Roles we setup:
# * Customer Support
# * Product Manager
# * Sales Engineer
#
# > Each role will answer differently focusing on their domain.
#
# ## Role-playing prompts
#
# * Tell model to "**act as**" as "**specific role**"

# %%
from utils import  *

# %%
system_prompt = "Act as an expert financial analyst"
user_prompt = "Offer insights into retirement planning for individuals approaching retirement age."

print(get_response(system_prompt,user_prompt))
# Out:
# Retirement planning is a critical process for individuals approaching retirement age, as it ensures financial security and peace of mind during the later stages of life. Here are several key insights and strategies to consider:
#
# ### 1. **Assess Your Current Financial Situation**
#    - **Net Worth Calculation**: Start by calculating your net worth, including all assets (savings, investments, real estate) and liabilities (debts, mortgages).
#    - **Income Sources**: Identify all potential income sources in retirement, such as Social Security, pensions, annuities, and investment income.
#
# ### 2. **Understand Retirement Expenses**
#    - **Estimate Living Expenses**: Consider your expected monthly expenses in retirement, including housing, healthcare, travel, and leisure activities.
#    - **Healthcare Costs**: Factor in potential healthcare costs, which can be significant. Consider long-term care insurance as a hedge against unexpected medical expenses.
#
# ### 3. **Social Security Strategy**
#    - **Timing Benefits**: Decide when to start taking Social Security benefits. Delaying benefits can increase your monthly payout, but it’s essential to weigh this against your health and financial needs.
#    - **Spousal Benefits**: If married, explore strategies for maximizing spousal benefits, which can significantly impact overall retirement income.
#
# ### 4. **Investment Strategy**
#    - **Asset Allocation**: As you approach retirement, consider shifting your asset allocation to reduce risk. A more conservative portfolio can help protect your savings from market volatility.
#    - **Withdrawal Strategy**: Develop a sustainable withdrawal strategy, often referred to as the "4% rule," which suggests withdrawing 4% of your retirement savings annually. Adjust this based on your specific situation and market conditions.
#
# ### 5. **Tax Planning**
#    - **Tax-Advantaged Accounts**: Utilize tax-advantaged accounts like IRAs and 401(k)s effectively. Understand the tax implications of withdrawals and consider strategies to minimize taxes in retirement.
#    - **Roth Conversions**: Consider converting traditional IRAs to Roth IRAs to take advantage of tax-free growth and withdrawals, especially if you expect to be in a higher tax bracket in the future.
#
# ### 6. **Emergency Fund**
#    - **Liquidity Needs**: Maintain an emergency fund to cover unexpected expenses without having to dip into retirement accounts, which can incur penalties and taxes.
#
# ### 7. **Estate Planning**
#    - **Wills and Trusts**: Ensure you have a will and consider setting up trusts to manage your estate and minimize estate taxes.
#    - **Beneficiary Designations**: Regularly review and update beneficiary designations on retirement accounts and insurance policies.
#
# ### 8. **Lifestyle Considerations**
#    - **Retirement Lifestyle**: Think about how you want to spend your retirement. Will you travel, volunteer, or pursue hobbies? This can impact your financial planning.
#    - **Part-Time Work**: Consider the possibility of part-time work or consulting to supplement income and stay engaged.
#
# ### 9. **Professional Guidance**
#    - **Financial Advisor**: Consult with a financial advisor who specializes in retirement planning. They can provide personalized advice and help you navigate complex financial decisions.
#
# ### 10. **Regular Review and Adjustments**
#    - **Annual Review**: Regularly review your retirement plan and adjust it as necessary based on changes in your financial situation, market conditions, and personal goals.
#
# ### Conclusion
# Retirement planning is a dynamic process that requires careful consideration of various factors. By taking a proactive approach and utilizing these strategies, individuals approaching retirement can enhance their financial security and enjoy a fulfilling retirement.

# %% [markdown]
# # More Effective Role-Playing
#
# * Specific requirements within the role
# * Incorporate traits like personality and expertise

# %%
system_prompt = """ 
Act as a seasoned technology journalist covering the latest trends in the tech industry.
You are known for your thorough research and insightful analysis.
"""

user_prompt = "What is the impact of artificial intelligence on job markets?"

print(get_response(system_prompt,user_prompt))
# Out:
# The impact of artificial intelligence (AI) on job markets is a multifaceted issue that has garnered significant attention from economists, technologists, and policymakers alike. As we navigate through 2023, several key trends and implications have emerged, shaping the future of work in profound ways.
#
# ### 1. **Job Displacement vs. Job Creation**
#
# One of the most discussed aspects of AI's impact on employment is the potential for job displacement. Automation technologies, powered by AI, are increasingly capable of performing tasks traditionally done by humans, particularly in sectors like manufacturing, logistics, and customer service. For instance, chatbots and virtual assistants are streamlining customer interactions, while robotic process automation (RPA) is handling repetitive tasks in finance and administration.
#
# However, while certain jobs may be at risk, AI also has the potential to create new roles. The World Economic Forum's "Future of Jobs Report" has consistently highlighted that while 85 million jobs may be displaced by 2025, 97 million new roles could emerge that are more suited to the new division of labor between humans and machines. These new jobs often require skills in AI management, data analysis, and other tech-centric fields.
#
# ### 2. **Skill Shifts and Workforce Reskilling**
#
# As AI technologies evolve, so too does the skill set required in the workforce. There is a growing demand for workers who can collaborate with AI systems, interpret data, and leverage AI tools to enhance productivity. This shift necessitates a robust focus on reskilling and upskilling initiatives. Companies are increasingly investing in training programs to help their employees adapt to new technologies, while educational institutions are revising curricula to include AI literacy and data science.
#
# The emphasis on soft skills—such as creativity, emotional intelligence, and critical thinking—has also gained traction, as these are areas where humans still outperform machines. The ability to work alongside AI, rather than be replaced by it, is becoming a crucial competency.
#
# ### 3. **Sector-Specific Impacts**
#
# The effects of AI on job markets are not uniform across all sectors. Industries such as healthcare, finance, and technology are experiencing significant transformations. In healthcare, AI is enhancing diagnostic capabilities and patient care, leading to new roles in health informatics and telemedicine. In finance, AI-driven algorithms are optimizing trading and risk assessment, creating demand for data analysts and compliance experts.
#
# Conversely, sectors like retail and manufacturing may face more immediate job losses due to automation. The challenge lies in ensuring that workers in these industries can transition to new roles, which may require geographic mobility and additional training.
#
# ### 4. **Economic Inequality and Job Polarization**
#
# AI's impact on job markets also raises concerns about economic inequality. The benefits of AI are often concentrated among those with advanced skills and education, potentially widening the gap between high- and low-income workers. Job polarization is another concern, where middle-skill jobs decline while low-skill and high-skill jobs proliferate, leading to a bifurcated labor market.
#
# Policymakers are tasked with addressing these disparities through social safety nets, tax reforms, and educational initiatives that promote equitable access to training and job opportunities.
#
# ### 5. **Regulatory and Ethical Considerations**
#
# As AI continues to reshape job markets, regulatory frameworks will need to evolve. Issues such as data privacy, algorithmic bias, and the ethical use of AI in hiring practices are critical areas that require attention. Ensuring that AI systems are transparent and fair will be essential in maintaining public trust and protecting workers' rights.
#
# ### Conclusion
#
# The impact of AI on job markets is complex and dynamic, characterized by both challenges and opportunities. While the potential for job displacement is real, the creation of new roles and the demand for advanced skills present a pathway for adaptation. As we move forward, a collaborative approach involving businesses, educators, and policymakers will be crucial in navigating this transition and ensuring that the workforce is prepared for the future of work in an AI-driven economy.

# %% [markdown]
# ## Role-Playing with Requirements
#
# * We can specify response guidelines and behavior guidance in role-playing prompts.

# %%
system_prompt = """ 
Act as a seasoned technology journalist covering the latest trends in the tech industry. You're known for you in-depth research and insightful analysis.
If the question is related to tech, you answer to the best of your knowledge.
Otherwise, you just respond with 'I am trained to only discuss technology topics.'
"""

user_prompt= "Which American literature books do you recommend?"

print(get_response(system_prompt, user_prompt))
# Out:
# I am trained to only discuss technology topics.
