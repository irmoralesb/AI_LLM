# %% [markdown]
# # Prompt Engineering
#
# ## Examples

# %%
from utils import *

# %% [markdown]
# Basic example

# %%
prompt = "What is prompt engineering?"
response = get_response(prompt)
print(response)
# Out:
# Prompt engineering is the process of designing and creating prompts that are used in various applications, such as chatbots, surveys, and interactive systems. This involves crafting prompts that are clear, concise, and effective in eliciting the desired response or information from users. Prompt engineering also involves considering factors such as user experience, language, tone, and context to ensure that prompts are engaging and user-friendly.

# %% [markdown]
# > Prompt engineering is the process of designing and creating prompts that are used in various applications, such as chatbots, surveys, and interactive systems. This involves crafting prompts that are clear, concise, and effective in eliciting the desired response or information from users. Prompt engineering also involves considering factors such as user experience, language, tone, and context to ensure that prompts are engaging and user-friendly.

# %%
prompt = "What is prompt engineering? Explain it in terms that can be understood by a 5-year-old"
response = get_response(prompt)
print(response)
# Out:
# Prompt engineering is like building a fun game or puzzle for your brain to solve. It's like giving your brain a little challenge to figure out and see how creative you can be. Just like when you play with blocks or put together a puzzle, prompt engineering is about using your imagination and problem-solving skills to come up with cool ideas and solutions.

# %% [markdown]
# > Prompt engineering is like building a fun game or puzzle for your brain to solve. It's like giving your brain a little challenge to figure out and see how creative you can be. Just like when you play with blocks or put together a puzzle, prompt engineering is about using your imagination and problem-solving skills to come up with cool ideas and solutions.
