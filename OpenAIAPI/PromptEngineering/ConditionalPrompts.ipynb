# %% [markdown]
# # Conditional Prompts
#
# * Incorporate logic or conditions
# * Conditional prompts follow an if-else style

# %% [markdown]
# ## Example
#
# Provide a title only for English text

# %%
from utils import *

text = "Once upon a time in a quaint little village, there lived a curious young boy named David. David was [...]"

prompt = f"""
You will be provided with a text delimited by triple  backticks.
If the text is written in English, suggest a suitable title for it.
Otherwise, write 'I only understand English'
```{text}```
"""

print_response(prompt)
# Out:
# Title: The Adventures of David

# %%
text = "Érase una vez, en un pequeño y pintoresco pueblo, vivía un joven y curioso niño llamado David. David era"

prompt = f"""
You will be provided with a text delimited by triple  backticks.
If the text is written in English, suggest a suitable title for it.
Otherwise, write 'I only understand English'
```{text}```
"""

print_response(prompt)
# Out:
# I only understand English

# %% [markdown]
# ## Multiple Conditions
#
# * Can incorporate multiple conditions

# %%
text = "In the heart of the forest, sunlight filters the lush green canopy, creating a tranquil atmosphere [...]"

prompt = f"""
    You will be provided with a text delimited by triple backticks.
    If the text is written in English, check if it contains the keyword 'technology'
    If it does, suggest a suitable for it, otherwise, write 'Keyword not found'.
    If the text is not written in English, reply with 'I only understand English'

    ```{text}```
"""

print_response(prompt)
# Out:
# Keyword not found
