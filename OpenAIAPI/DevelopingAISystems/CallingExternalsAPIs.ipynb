# %% [markdown]
# # Calling External APIs
#
# ## Request library

# %%
from openai import OpenAI
import requests


def get_artwork(keyword):
    url = 'https://api.artic.edu/api/v1/artworks/search'
    querystring = {"q": keyword}
    response_value = requests.request("GET", url, params=querystring)
    return response_value.text


print(get_artwork('phantom'))
# Out:
# {"preference":null,"pagination":{"total":40,"limit":10,"offset":0,"total_pages":4,"current_page":1},"data":[{"_score":115.01322,"id":129937,"api_model":"artworks","api_link":"https:\/\/api.artic.edu\/api\/v1\/artworks\/129937","is_boosted":false,"title":"A Phantom Crumbles","thumbnail":{"lqip":"...\","width":3000,"height":2072,"alt_text":"A work made of pen and black ink, with watercolor on cream laid paper, laid down on paperboard."},"timestamp":"2025-12-05T22:38:52-06:00"},{"_score":78.78794,"id":26236,"api_model":"artworks","api_link":"https:\/\/api.artic.edu\/api\/v1\/artworks\/26236","is_boosted":false,"title":"Landscape with Phantoms","thumbnail":{"lqip":"...\/byefl1urn1uzp1+z
# ...

# %% [markdown]
# ```
# {
#     "preference": null,
#     "pagination": {
#         "total": 40,
#         "limit": 10,
#         "offset": 0,
#         "total_pages": 4,
#         "current_page": 1
#     },
#     "data": [
#         {
#             "_score": 115.01322,
#             "id": 129937,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/129937",
#             "is_boosted": false,
#             "title": "A Phantom Crumbles",
#             "thumbnail": {
#                 "lqip": "...\",
#                 "width": 3000,
#                 "height": 2072,
#                 "alt_text": "A work made of pen and black ink, with watercolor on cream laid paper, laid down on paperboard."
#             },
#             "timestamp": "2025-12-05T22:38:52-06:00"
#         },
#         {
#             "_score": 78.78794,
#             "id": 26236,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/26236",
#             "is_boosted": false,
#             "title": "Landscape with Phantoms",
#             "thumbnail": {
#                 "lqip": "...\/byefl1urn1uzp1+zo2e7q2fr25fz45v\/76QAAAAAAACH5BAAAAAAALAAAAAAGAAUAAAUYYIdJTsVNQQEQ2jMYh3JRArIkmdVATLSFADs=",
#                 "width": 3000,
#                 "height": 2309,
#                 "alt_text": "A work made of lithograph on paper."
#             },
#             "timestamp": "2025-12-05T22:17:46-06:00"
#         },
#         {
#             "_score": 72.23333,
#             "id": 105714,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/105714",
#             "is_boosted": false,
#             "title": "The Phantom Ship",
#             "thumbnail": {
#                 "lqip": "...\/Hu6PLu6fTw6\/Xy7Pbz7vf07vj17\/f08Pj18Pv48\/369QAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACH5BAAAAAAALAAAAAAHAAUAAAYhQEvlAaFMMB8GQXFweEKDgABgAHUahQRi8YlkOBfNRhIEADs=",
#                 "width": 3000,
#                 "height": 2126,
#                 "alt_text": "A work made of lithograph in black on white wove paper."
#             },
#             "timestamp": "2025-12-05T22:33:45-06:00"
#         },
#         {
#             "_score": 53.90176,
#             "id": 44895,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/44895",
#             "is_boosted": false,
#             "title": "Soldiers Frightened by a Phantom, from Disparates, published as plate 2 in Los Proverbios",
#             "thumbnail": {
#                 "lqip": "...\",
#                 "width": 3000,
#                 "height": 2025,
#                 "alt_text": "A work made of etching and burnished aquatint in brown-black on ivory wove paper."
#             },
#             "timestamp": "2025-12-05T22:21:11-06:00"
#         },
#         {
#             "_score": 37.821224,
#             "id": 250751,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/250751",
#             "is_boosted": false,
#             "title": "PHANTOM. Mies as Rendered Society",
#             "thumbnail": {
#                 "lqip": "...\/t8fHw8rJw83JwMnJx83NxtPRzAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACH5BAAAAAAALAAAAAAIAAUAAAYlwE4GU7lwPiESIzCwiEYnU0FAACxAJY+GImlMIhwH4mBIKB6QIAA7",
#                 "width": 8688,
#                 "height": 5792,
#                 "alt_text": "A work made of mixed media installation."
#             },
#             "timestamp": "2025-12-05T22:55:41-06:00"
#         },
#         {
#             "_score": 37.035053,
#             "id": 49208,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/49208",
#             "is_boosted": false,
#             "title": "The Fall of Phaeton",
#             "thumbnail": {
#                 "lqip": "...\/ao6Dbo2EbZOGZaCTdauVc6uXd6eee7Sge6yfgLejgbWlg7Gmh7akhrqnhresirqrisGxj83CnAAAAAAAACH5BAAAAAAALAAAAAAGAAUAAAUY4HAgBgEUU8VtS9RZUIY5kkZdTyAoScOEADs=",
#                 "width": 2544,
#                 "height": 2126,
#                 "alt_text": "A work made of wool and silk, slit and double interlocking tapestry weave."
#             },
#             "timestamp": "2025-12-05T23:20:08-06:00"
#         },
#         {
#             "_score": 36.49366,
#             "id": 102098,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/102098",
#             "is_boosted": false,
#             "title": "Phaeton Driving the Chariot of Phoebus",
#             "thumbnail": {
#                 "lqip": "...",
#                 "width": 2222,
#                 "height": 2250,
#                 "alt_text": "A work made of tempera or distemper on canvas."
#             },
#             "timestamp": "2025-12-05T22:32:51-06:00"
#         },
#         {
#             "_score": 32.5936,
#             "id": 202269,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/202269",
#             "is_boosted": false,
#             "title": "All Night Long the Phantom of Unhappy Patroklos Stood Over Achilleus, plate 44 from Drawings for The Iliad",
#             "thumbnail": {
#                 "lqip": "...\/bz97czt7cz9\/dz9\/c0N\/d0OXj1ebi1enm2erm2Onm2u3p3e3r3+\/s3\/Dt3\/Lw5AAAAAAAACH5BAAAAAAALAAAAAAGAAUAAAUY4IZFVHVpi3FYmQIIQ+IwAYEUUjc1D8SFADs=",
#                 "width": 3000,
#                 "height": 2344,
#                 "alt_text": "A work made of lithograph on ivory laid paper."
#             },
#             "timestamp": "2025-12-05T22:48:52-06:00"
#         },
#         {
#             "_score": 31.83935,
#             "id": 20155,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/20155",
#             "is_boosted": false,
#             "title": "Apollo Granting Phaeton Permission to Drive the Chariot of the Sun",
#             "thumbnail": {
#                 "lqip": "...\",
#                 "width": 3000,
#                 "height": 1935,
#                 "alt_text": "A work made of oil on canvas."
#             },
#             "timestamp": "2025-12-05T22:16:18-06:00"
#         },
#         {
#             "_score": 30.587017,
#             "id": 106668,
#             "api_model": "artworks",
#             "api_link": "https:\/\/api.artic.edu\/api\/v1\/artworks\/106668",
#             "is_boosted": false,
#             "title": "The Fall of Phaeton",
#             "thumbnail": {
#                 "lqip": "...",
#                 "width": 531,
#                 "height": 768,
#                 "alt_text": "A work made of engraving on paper."
#             },
#             "timestamp": "2025-12-05T22:33:54-06:00"
#         }
#     ],
#     "info": {
#         "license_text": "The `description` field in this response is licensed under a Creative Commons Attribution 4.0 Generic License (CC-By) and the Terms and Conditions of artic.edu. All other data in this response is licensed under a Creative Commons Zero (CC0) 1.0 designation and the Terms and Conditions of artic.edu.",
#         "license_links": [
#             "https:\/\/creativecommons.org\/publicdomain\/zero\/1.0\/",
#             "https:\/\/www.artic.edu\/terms"
#         ],
#         "version": "1.13"
#     },
#     "config": {
#         "iiif_url": "https:\/\/www.artic.edu\/iiif\/2",
#         "website_url": "http:\/\/www.artic.edu"
#     }
# }
# ```

# %% [markdown]
# ## Adding context

# %%
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()

# %%
function_definition = [{
    "type": "function",
    "function": {
        "name": "get_artwork",
        "description": "This function call the Art Institute of Chicago API to find artwork that matches a keyword",
        "parameters": {
            "type": "object",
            "properties": {
                'keyword': {
                    "type": "string",
                    "description": "The keyword to be passed to the get_artwork function."
                }
            },
            'required': ["keyword"]
        }
    }
}]

response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=
    [{
        "role": "system",
        "content": "You are an AI assistant, a specialist in history of art. You should interpret the user prompt, and based on it extract one keyword for recommending artwork related to their preference."
    }, {
        "role": "user",
        "content": "I don't have much time to visit the museum and would like some recommendations. I like the seaside and quiet places."
    }],
    tools=function_definition
)

# %%
import json

if response.choices[0].finish_reason == 'tool_calls':
    function_call = response.choices[0].message.tool_calls[0].function
    if function_call.name == "get_artwork":
        artwork_keyword = json.loads(function_call.arguments)["keyword"]
        artwork = get_artwork(artwork_keyword)
        if artwork:
            print(
                f"""Here are some recommendations:
                    {[recom['title'] for recom in json.loads(artwork)["data"]]}""")
        else:
            print("Apologies, I couldn't make any recommendations based in the request.")
    else:
        print("Apologies, I couldn't func any artwork")
else:
    print("I am sorry, but I could not understand your request")
# Out:
# Here are some recommendations:
#                     ['Seaside, Port of Honfleur', 'Little Landscape at the Seaside (Kleine Landschaft am Meer)', 'Museum of Contemporary Art, Niterói, Rio de Janeiro, Brazil, Four Sketches', 'A seaside outing', 'Waitress at a Seaside Teahouse', 'Summer Landscape with Letter Forms', 'Seaside Excursions Southend', 'US Post Office, Seaside, Florida, from the series "Sweet Earth: Experimental Utopias in America"', 'Rustic Seaside Scene', 'A Holiday']

# %% [markdown]
# Another example, notice the use of `"result"`
#
# ```
# client = OpenAI(api_key="<OPENAI_API_TOKEN>")
#
# # Define the function to pass to tools
# function_definition = [{"type": "function",
#                         "function" : {"name": "get_airport_info",
#                                       "description": "This function calls the Aviation API to return the airport code corresponding to the airport in the request",
#                                       "parameters": {"type": "object",
#                                                      "properties": {"airport_code": {"type": "string","description": "The code to be passed to the get_airport_info function."}} },
#                                       "result": {"type": "string"} } } ]
#
# response = get_response(function_definition)
# print(response)
# ```
